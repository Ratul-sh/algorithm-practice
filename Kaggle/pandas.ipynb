# %%
import pandas as pd
import numpy as np
df = pd.read_csv("E:\\journey_2_ds\\kaggle\\fifa_world_cup_2026_player_performance.csv")
df.head()
print(df["height_cm"].mean())
print(df["height_cm"].max())
print(df["height_cm"].min())
# Out:
# 181.65434065934065
# 200
# 163
